# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'


physical_devices = tf.config.experimental.list_physical_devices('GPU') 
if len(physical_devices) > 0: 
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# # Load the Fashion MNIST dataset

# %%
fashion_mnist = keras.datasets.fashion_mnist

# %% [markdown]
# # Split the dataset into training and testing sets

# %%
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# # Scale the pixel values to a range of 0 to 1

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# # Define the class names

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # Create a neural network model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# # Compile the model

# %%
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])

# %% [markdown]
# # Train the model

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.4968 - accuracy: 0.8253
# Epoch 2/10
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.3798 - accuracy: 0.8629
# Epoch 3/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.3416 - accuracy: 0.8752
# Epoch 4/10
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.3150 - accuracy: 0.8855
# Epoch 5/10
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2966 - accuracy: 0.8903
# Epoch 6/10
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.2810 - accuracy: 0.8973
# Epoch 7/10
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.2688 - accuracy: 0.8996
# Epoch 8/10
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.2574 - accuracy: 0.9038
# Epoch 9/10
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.2470 - accuracy: 0.9084
# Epoch 10/10
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.2389 - accuracy: 0.9103

# %% [markdown]
# # Evaluate the model on the testing set

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 5s 14ms/step - loss: 0.3578 - accuracy: 0.8755
# Test accuracy: 0.8755000233650208

# %%
def showImage(x, y, index):
    plt.figure(figsize=(15,2))
    plt.imshow(x[index])
    plt.xlabel(class_names[y[index]])

# %%
for n in range(0,20):
    showImage(test_images, test_labels, n)
